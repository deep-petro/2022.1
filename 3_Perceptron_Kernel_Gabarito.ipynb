# %% [markdown]
# # Perceptron (Aprendizado Profundo - UFMG)
#
# ## Preâmbulo
#
# Imports e configurando os plots

# %%
from sklearn.datasets import make_blobs
from sklearn.datasets import make_circles

import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.optim as optim

# %%
plt.rcParams['figure.figsize'] = (8, 5)

plt.rcParams['axes.axisbelow'] = True 
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['axes.spines.bottom'] = True
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.ymargin'] = 0.1

plt.rcParams['font.family'] = 'serif'

plt.rcParams['axes.grid'] = True
plt.rcParams['grid.color'] = 'lightgrey'
plt.rcParams['grid.linewidth'] = .1

plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.direction'] = 'out' 
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['xtick.minor.width'] = .5
plt.rcParams['xtick.minor.visible'] = True

plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['ytick.minor.width'] = .5
plt.rcParams['ytick.minor.visible'] = True

plt.rcParams['legend.fontsize'] = 16

plt.rcParams['lines.linewidth'] = 4
plt.rcParams['lines.markersize'] = 10

plt.rcParams['font.family'] = 'serif'

plt.rcParams['axes.grid'] = True
plt.rcParams['grid.color'] = 'lightgrey'
plt.rcParams['grid.linewidth'] = .1

plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.direction'] = 'out' 
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['xtick.minor.width'] = .5
plt.rcParams['xtick.minor.visible'] = True

plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.direction'] = 'out'
plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['ytick.minor.width'] = .5
plt.rcParams['ytick.minor.visible'] = True

plt.rcParams['legend.fontsize'] = 16

plt.rcParams['lines.linewidth'] = 4
plt.rcParams['lines.markersize'] = 10

# %%
plt.style.use('tableau-colorblind10') # use um estilo colorblind!
plt.ion()

# %% [markdown]
# Para testar o resultado dos seus algoritmos vamos usar o módulo testing do numpy.

# %%
from numpy.testing import assert_equal
from numpy.testing import assert_almost_equal
from numpy.testing import assert_array_almost_equal

# %% [markdown]
# ## Conjunto de Problemas 1: Perceptron from Scratch
#
# Por fim, vamos implementar uma primeira versão do Perceptron usando pytorch. Inicialmente, vamos gerar dois blobs linearmente separáveis. Com um seed bem setado, claramente teremos duas classes abaixo.

# %%
state = np.random.seed(20190187)

# %%
## cria um dataset com 2 features, com 2 "centros". Cada centro equivale a uma classe, então os pontos
## de um centro são considerados de uma classe (por exemplo classe 0) e o outro da outra classe (classe 1)
X, y = make_blobs(n_samples=200, n_features=2, centers=2)

# _, ax = plt.subplots(figsize=(8, 9))
# ax.scatter(X[:,0], X[:,1], c=y, edgecolor='w', alpha=0.75)

## os pontos da classe 0 e 1 estão distribuidos aleatoriamente nas linhas de X. Aqui pegamos os indices dos
## pontos de cada classe.
idx_1 = y == 1
idx_2 = np.logical_not(idx_1)

plt.scatter(X[idx_1, 0], X[idx_1, 1], s=80, edgecolors='k', label='class 1')
plt.scatter(X[idx_2, 0], X[idx_2, 1], s=80, edgecolors='k', label='class 2')
plt.legend()
plt.show();

# %% [markdown]
# Para realizar as nossas previsões, precisamos aplicar a seguinte função:
#
# $$\hat{y}_i = sign(1 + \theta_1 x_{i1} + \theta_1 x_{i2} + \cdots + \theta_d x_{id})$$
#
# 8. Sabendo que precisamos de uma coluna de valores 1 na nossa entrada $\mathbf{X}$, implemente uma função chamada `add_intercept` que adicionar uma nova coluna em X. A mesma deve retornar uma cópia! Não altere a matriz original.

# %%
def add_intercept(X: np.ndarray) -> np.ndarray:
    ## implemente
    pass

# %%
# testes, não apague!
X_teste = torch.zeros(4, 4)
X_novo_teste = add_intercept(X_teste)
assert_equal(X_teste.shape[0], X_novo_teste.shape[0])
assert_equal(X_teste.shape[1] + 1, X_novo_teste.shape[1])
assert_array_almost_equal(np.ones(X_novo_teste.shape[0]), X_novo_teste[:, 0])

# %% [markdown]
# 10. Por fim, implemente agora o algoritmo do perceptron. O mesmo deve retornar um vetor de parâmetros theta. Execute o mesmo em X (com ou sem intercepto, no nosso exemplo simples não importa muito).

# %%
state = np.random.seed(20190187)
X, y = make_blobs(n_samples=200, n_features=2, centers=2)

_, ax = plt.subplots(figsize=(8, 9))
ax.scatter(X[:,0], X[:,1], c=y, edgecolor='w', alpha=0.75)
plt.show();

# %%
def perceptron(X: np.ndarray, y: np.ndarray, lr: float) -> np.ndarray:
    ## implemente
    return w
w = perceptron(X, y, 0.05)

# %% [markdown]
# Seu perceptron deve prever perfeitamente as classes! Vamos plotar a reta do parâmetros $\theta$ e verificar isto!

# %%
def perceptron_with_plot(X: np.ndarray, y: np.ndarray, lr: float) -> np.ndarray:
    ## implemente

    change = True
    while change:
        change = False
        
        for i in range(X.shape[0]):

            ## implemente: a atualização de w de acordo com o ponto "i" dos dados
            
            if ŷi != yi:
                ## 
                fig, ax = plt.subplots(figsize=(8, 9))
                ax.scatter(X[:,1], X[:,2], c=y, edgecolor='w', alpha=0.75)
                ax.scatter([xi[1]], [xi[2]], edgecolor='r')

                x2 = -((w[1] * x1) / w[2]) - (w[0]/w[2])
                ax.plot(x1, x2, color='grey', ls='--', lw=1, label='Old Line')

                ## implemente aqui a atualização dos pesos w
                w = w + #....
                change = True

                x2 = -((w[1] * x1) / w[2]) - (w[0]/w[2])
                ax.plot(x1, x2, color='k', ls='-', lw=1, label='New Line')
                ax.set(xlim=(-10, 1), ylim=(-10, 5))
                ax.legend()
                fig.show()
    return w
w = perceptron_with_plot(X, y, 0.05)

# %% [markdown]
# ## Conjunto de Problemas 2: Perceptron com Kernel
#
# Embora o perceptron não funcione quando a base não é linearmente separável, podemos fazer uso de um truque de kernel para tais casos.
#
# Primeiramente vamos criar uma base não linearmente separável abaixo.

# %%
X, y = make_circles(n_samples=1000, random_state=42)
_, ax = plt.subplots(figsize=(8, 9))
ax.scatter(X[:,0], X[:,1], c=y, edgecolor='w', alpha=0.75)

# %% [markdown]
# 1. Crie uma nova matriz X que simula um kernel polinomial de grau dois. Para isto, uma nova base de dados deve ser criada, onde cada linha tem 5 dimensões da seguinte forma:
#
# $$ \mathbf{x}_i = <x_1, x_2, x_1^2, x_2^2, x_0 \cdot x_1 > $$
#
# Teste se tal alteração funciona na base acima.

# %%
## implemente aqui o kernel para os dados X e crie o array Xn com os dados transformados

# %%
perceptron(Xn, y, lr=0.05)

# %% [markdown]
# 2. **DESAFIO:** Plote a decision boundary.
